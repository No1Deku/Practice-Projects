# %%
import skimpy as sk
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\\Admin\\Downloads\\archive (17)\\dirty_cafe_sales.csv")

# %%
sk.skim(data)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 10000  │ │ string      │ 8     │                                                          │
# │ │ Number of columns │ 8      │ └─────────────┴───────┘                                                          │
# │ └───────────────────┴────────┘                                                                                  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┓  │
# │ ┃           ┃      ┃       ┃           ┃           ┃           ┃           ┃ chars    ┃ words per ┃ total    ┃  │
# │ ┃ column    ┃ NA   ┃ NA %  ┃ shortest  ┃ longest   ┃ min       ┃ max       ┃ per row  ┃ row       ┃ words    ┃  │
# │ ┡━━━━━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━┩  │
# │ │ Transacti │    0 │     0 │ TXN_19613 │ TXN_19613 │ TXN_10005 │ TXN_99991 │       11 │         1 │    10000 │  │
# │ │ on ID     │      │       │ 73        │ 73        │ 55        │ 24        │          │           │          │  │
# │ │ Item      │  333 │  3.33 │ Tea       │ Smoothie  │ Cake      │ UNKNOWN   │     5.65 │      0.97 │     9667 │  │
# │ │ Quantity  │  138 │  1.38 │ 2         │ UNKNOWN   │ 1         │ UNKNOWN   │     1.17 │      0.99 │     9862 │  │
# │ │ Price Per │  179 │  1.79 │ 2.0       │ UNKNOWN   │ 1.0       │ UNKNOWN   │     3.11 │      0.98 │     9821 │  │
# │ │ Unit      │      │       │           │           │           │           │          │           │          │  │
# │ │ Total     │  173 │  1.73 │ 4.0       │ UNKNOWN   │ 1.0       │ UNKNOWN   │     3.47 │      0.98 │     9827 │  │
# │ │ Spent     │      │       │           │           │           │           │          │           │          │  │
# │ │ Payment   │ 2579 │ 25.79 │ Cash      │ Digital   │ Cash      │ UNKNOWN   │     9.39 │       1.2 │    11985 │  │
# │ │ Method    │      │       │           │ Wallet    │           │           │          │           │          │  │
# │ │ Location  │ 3265 │ 32.65 │ ERROR     │ Takeaway  │ ERROR     │ UNKNOWN   │     7.79 │      0.67 │     6735 │  │
# │ │ Transacti │  159 │  1.59 │ ERROR     │ 2023-09-0 │ 2023-01-0 │ UNKNOWN   │     9.88 │      0.98 │     9841 │  │
# │ │ on Date   │      │       │           │ 8         │ 1         │           │          │           │          │  │
# │ └───────────┴──────┴───────┴───────────┴───────────┴───────────┴───────────┴──────────┴───────────┴──────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
data.head(25)
# Out:
#    Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0     TXN_1961373    Coffee        2            2.0         4.0
# 1     TXN_4977031      Cake        4            3.0        12.0
# 2     TXN_4271903    Cookie        4            1.0       ERROR
# 3     TXN_7034554     Salad        2            5.0        10.0
# 4     TXN_3160411    Coffee        2            2.0         4.0
# 5     TXN_2602893  Smoothie        5            4.0        20.0
# 6     TXN_4433211   UNKNOWN        3            3.0         9.0
# 7     TXN_6699534  Sandwich        4            4.0        16.0
# 8     TXN_4717867       NaN        5            3.0        15.0
# 9     TXN_2064365  Sandwich        5            4.0        20.0
# 10    TXN_2548360     Salad        5            5.0        25.0
# 11    TXN_3051279  Sandwich        2            4.0         8.0
# 12    TXN_7619095  Sandwich        2            4.0         8.0
# 13    TXN_9437049    Cookie        5            1.0         5.0
# 14    TXN_8915701     ERROR        2            1.5         3.0
# 15    TXN_2847255     Salad        3            5.0        15.0
# 16    TXN_3765707  Sandwich        1            4.0         4.0
# 17    TXN_6769710     Juice        2            3.0         6.0
# 18    TXN_8876618      Cake        5            3.0        15.0
# 19    TXN_3709394     Juice        4            3.0        12.0
# 20    TXN_3522028  Smoothie    ERROR            4.0        20.0
# 21    TXN_3567645  Smoothie        4            4.0        16.0
# 22    TXN_5132361  Sandwich        3            4.0        12.0
# 23    TXN_2616390  Sandwich        2            4.0         8.0
# 24    TXN_9400181  Sandwich        5            4.0        20.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 2      Credit Card  In-store       2023-07-19
# 3          UNKNOWN   UNKNOWN       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card       NaN       2023-03-31
# 6            ERROR  Takeaway       2023-10-06
# 7             Cash   UNKNOWN       2023-10-28
# 8              NaN  Takeaway       2023-07-28
# 9              NaN  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 11     Credit Card  Takeaway            ERROR
# 12            Cash  In-store       2023-05-03
# 13             NaN  Takeaway       2023-06-01
# 14             NaN  In-store       2023-03-21
# 15     Credit Card  In-store       2023-11-15
# 16             NaN       NaN       2023-06-10
# 17            Cash  In-store       2023-02-24
# 18            Cash     ERROR       2023-03-25
# 19            Cash  Takeaway       2023-01-15
# 20            Cash  In-store       2023-04-04
# 21     Credit Card  Takeaway       2023-03-30
# 22  Digital Wallet  Takeaway       2023-12-01
# 23             NaN       NaN       2023-09-18
# 24            Cash  In-store       2023-06-03

# %%
data.columns = [col.strip().replace(" ","_").lower() for col in data.columns]
data.columns
# Out:
# Index(['transaction_id', 'item', 'quantity', 'price_per_unit', 'total_spent',
#        'payment_method', 'location', 'transaction_date'],
#       dtype='object')

# %%
for i in data.columns:
    grouped = data.groupby(i)[i].count()  
    print(f"Grouping by {i}:")
    print(grouped)
    print("-" * 40)
# Out:
# Grouping by transaction_id:
# transaction_id
# TXN_1000555    1
# TXN_1001832    1
# TXN_1002457    1
# TXN_1003246    1
# TXN_1004184    1
#               ..
# TXN_9996968    1
# TXN_9997263    1
# TXN_9997620    1
# TXN_9999113    1
# TXN_9999124    1
# Name: transaction_id, Length: 10000, dtype: int64
# ----------------------------------------
# Grouping by item:
# item
# Cake         962
# Coffee      1025
# Cookie       962
# Juice       1029
# Other       2118
# Salad       1013
# Sandwich    1000
# Smoothie     942
# Tea          949
# Name: item, dtype: int64
# ----------------------------------------
# Grouping by quantity:
# quantity
# 1          1822
# 2          1974
# 3          1849
# 4          1863
# 5          2013
# ERROR       170
# UNKNOWN     171
# Name: quantity, dtype: int64
# ----------------------------------------
# Grouping by price_per_unit:
# price_per_unit
# 1.0        1143
# 1.5        1133
# 2.0        1227
# 3.0        2429
# 4.0        2331
# 5.0        1204
# ERROR       190
# UNKNOWN     164
# Name: price_per_unit, dtype: int64
# ----------------------------------------
# Grouping by total_spent:
# total_spent
# 1.0        232
# 1.5        205
# 10.0       524
# 12.0       939
# 15.0       734
# 16.0       444
# 2.0        497
# 20.0       746
# 25.0       259
# 3.0        930
# 4.0        923
# 4.5        225
# 5.0        468
# 6.0        979
# 7.5        237
# 8.0        677
# 9.0        479
# ERROR      164
# UNKNOWN    165
# Name: total_spent, dtype: int64
# ----------------------------------------
# Grouping by payment_method:
# payment_method
# Cash              2258
# Credit Card       2273
# Digital Wallet    2291
# ERROR              306
# Other             2579
# UNKNOWN            293
# Name: payment_method, dtype: int64
# ----------------------------------------
# Grouping by location:
# location
# ERROR        358
# In-store    3017
# Other       3265
# Takeaway    3022
# UNKNOWN      338
# Name: location, dtype: int64
# ----------------------------------------
# Grouping by transaction_date:
# transaction_date
# 2023-01-01     20
# 2023-01-02     21
# 2023-01-03     21
# 2023-01-04     27
# 2023-01-05     38
#              ...
# 2023-12-29     25
# 2023-12-30     27
# 2023-12-31     20
# ERROR         142
# UNKNOWN       159
# Name: transaction_date, Length: 367, dtype: int64
# ----------------------------------------

# %%
nulls = ["ERROR","UNKNOWN"]

data.loc[data['item'].isin(nulls), 'item'] = np.nan
data.loc[data['payment_method'].isin(nulls), 'payment_method'] = np.nan
data.loc[data['location'].isin(nulls), 'location'] = np.nan
data.loc[data['transaction_date'].isin(nulls), 'transaction_date'] = np.nan
data.loc[data['quantity'].isin(nulls), 'quantity'] = np.nan
data.loc[data['price_per_unit'].isin(nulls), 'price_per_unit'] = np.nan
data.loc[data['total_spent'].isin(nulls), 'total_spent'] = np.nan

# %%
data.fillna({
    'item': "Other", 
    'location': "Undefined", 
    'payment_method': "Unknown"
}, inplace=True)

# %%
data['transaction_date'] = pd.to_datetime(data['transaction_date'],errors='coerce')

# %%
median_date = data['transaction_date'].median()  
data.fillna({'transaction_date': median_date}, inplace=True)

# %%
data = data.dropna(subset=['quantity','price_per_unit'], how='all')
data = data.dropna(subset=['quantity','total_spent'], how='all')
data = data.dropna(subset=['total_spent','price_per_unit'], how='all')

# %%
data['quantity'] = pd.to_numeric(data['quantity'],errors='coerce')
data['price_per_unit'] = pd.to_numeric(data['price_per_unit'],errors='coerce')
data['total_spent'] = pd.to_numeric(data['total_spent'],errors='coerce')

# %%
data['total_spent'] = data['total_spent'].fillna(data['quantity'] * data['price_per_unit'])

data['quantity'] = data['quantity'].fillna(data['total_spent'] / data['price_per_unit'])

data['price_per_unit'] = data['price_per_unit'].fillna(data['total_spent'] / data['quantity'])

# %%
data.head(25)
# Out:
#    transaction_id      item  quantity  price_per_unit  total_spent  \
# 0     TXN_1961373    Coffee       2.0             2.0          4.0
# 1     TXN_4977031      Cake       4.0             3.0         12.0
# 2     TXN_4271903    Cookie       4.0             1.0          4.0
# 3     TXN_7034554     Other       2.0             5.0         10.0
# 4     TXN_3160411    Coffee       2.0             2.0          4.0
# 5     TXN_2602893  Smoothie       5.0             4.0         20.0
# 6     TXN_4433211     Other       3.0             3.0          9.0
# 7     TXN_6699534     Other       4.0             4.0         16.0
# 8     TXN_4717867     Other       5.0             3.0         15.0
# 9     TXN_2064365  Sandwich       5.0             4.0         20.0
# 10    TXN_2548360     Salad       5.0             5.0         25.0
# 11    TXN_3051279  Sandwich       2.0             4.0          8.0
# 12    TXN_7619095  Sandwich       2.0             4.0          8.0
# 13    TXN_9437049    Cookie       5.0             1.0          5.0
# 14    TXN_8915701     Other       2.0             1.5          3.0
# 15    TXN_2847255     Salad       3.0             5.0         15.0
# 16    TXN_3765707  Sandwich       1.0             4.0          4.0
# 17    TXN_6769710     Juice       2.0             3.0          6.0
# 18    TXN_8876618     Other       5.0             3.0         15.0
# 19    TXN_3709394     Juice       4.0             3.0         12.0
# 20    TXN_3522028  Smoothie       5.0             4.0         20.0
# 21    TXN_3567645  Smoothie       4.0             4.0         16.0
# 22    TXN_5132361  Sandwich       3.0             4.0         12.0
# 23    TXN_2616390  Sandwich       2.0             4.0          8.0
# 24    TXN_9400181  Sandwich       5.0             4.0         20.0
#
#     payment_method   location transaction_date
# 0      Credit Card   Takeaway       2023-09-08
# 1             Cash   In-store       2023-05-16
# 2      Credit Card   In-store       2023-07-19
# 3          Unknown  Undefined       2023-04-27
# 4   Digital Wallet   In-store       2023-06-11
# 5      Credit Card      Other       2023-03-31
# 6          Unknown   Takeaway       2023-10-06
# 7             Cash  Undefined       2023-10-28
# 8            Other   Takeaway       2023-07-28
# 9            Other   In-store       2023-12-31
# 10            Cash   Takeaway       2023-11-07
# 11     Credit Card   Takeaway       2023-07-02
# 12            Cash   In-store       2023-05-03
# 13           Other   Takeaway       2023-06-01
# 14           Other   In-store       2023-03-21
# 15     Credit Card   In-store       2023-11-15
# 16           Other      Other       2023-06-10
# 17            Cash   In-store       2023-02-24
# 18            Cash  Undefined       2023-03-25
# 19            Cash   Takeaway       2023-01-15
# 20            Cash   In-store       2023-04-04
# 21     Credit Card   Takeaway       2023-03-30
# 22  Digital Wallet   Takeaway       2023-12-01
# 23           Other      Other       2023-09-18
# 24            Cash   In-store       2023-06-03

# %%
data.hist(figsize=(12, 8), bins=50, edgecolor="black")  
plt.suptitle("Distribution of Numeric Features", fontsize=14)  
plt.show()

# %%
sns.scatterplot(data=data,x=data['quantity'], y=data['total_spent'],hue = 'item' ,alpha=0.5)  
plt.title("Relationship between Quantity & Total_Spent Sold")  
plt.xlabel("Quantity")  
plt.ylabel("Total_Spent")  
plt.show()

# %%
plt.figure(figsize=(8, 5))  
sns.boxplot(y=data.groupby('item')['total_spent'].sum())  
plt.title("Boxplot of Price: Detecting Outliers")  
plt.show()

# %%
corr_matrix = data.corr(numeric_only=True)
sns.heatmap(corr_matrix, annot=True, cmap="YlGnBu")
# Out:
# <Axes: >
